# %% [markdown]
# ## Gráfico de Resultados en Kaggle

# %%
import pandas as pd

# Datos para el DataFrame
data = {
    'Public Score': [0.519, 0.609, 0.6, 0.605, 0.63, 0.635, 0.6, 0.596, 0.6, 0.639, 0.639, 0.639, 0.6, 0.618, 0.66],
    'Private Score': [0.544, 0.589, 0.551, 0.602, 0.57, 0.583, 0.551, 0.57, 0.525, 0.57, 0.57, 0.57, 0.557, 0.583, 0.602]
}

# Crea el DataFrame
df = pd.DataFrame(data)

# Muestra el DataFrame
print(df)
# Out:
#     Public Score  Private Score
# 0          0.519          0.544
# 1          0.609          0.589
# 2          0.600          0.551
# 3          0.605          0.602
# 4          0.630          0.570
# 5          0.635          0.583
# 6          0.600          0.551
# 7          0.596          0.570
# 8          0.600          0.525
# 9          0.639          0.570
# 10         0.639          0.570
# 11         0.639          0.570
# 12         0.600          0.557
# 13         0.618          0.583
# 14         0.660          0.602

# %%
import matplotlib.pyplot as plt

# Crea el gráfico
plt.figure(figsize=(10, 6))
plt.plot(df['Public Score'], label='Public Score')
plt.plot(df['Private Score'], label='Private Score')
plt.title('Evolution of Public and Private Scores')
plt.xlabel('Iteration')
plt.ylabel('Score')
plt.xticks(range(0, len(df), 1))  # Ajusta los ticks del eje x para que vayan de 1 en 1
plt.legend()

# Muestra el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Crea el gráfico
plt.figure(figsize=(10, 6))
plt.plot(df['Public Score'], label='Public Score')
plt.plot(df['Private Score'], label='Private Score')

# Añade las puntuaciones a cada punto
for i, score in enumerate(df['Public Score']):
    plt.text(i, score, str(score), ha='center', va='bottom')
for i, score in enumerate(df['Private Score']):
    plt.text(i, score, str(score), ha='center', va='top')

plt.title('Evolution of Public and Private Scores')
plt.xlabel('Iteration')
plt.ylabel('Score')
plt.xticks(range(0, len(df), 1))  # Ajusta los ticks del eje x para que vayan de 1 en 1
plt.legend()

# Muestra el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calcula las medias
public_score_mean = df['Public Score'].mean()
private_score_mean = df['Private Score'].mean()

# Crea el gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(df.index, df['Public Score'], label='Public Score')
plt.bar(df.index, df['Private Score'], label='Private Score', alpha=0.5)

# Añade las líneas de la media
plt.axhline(public_score_mean, color='blue', linestyle='dashed', linewidth=1)
plt.axhline(private_score_mean, color='orange', linestyle='dashed', linewidth=1)

# Añade las etiquetas de la media
plt.text(len(df), public_score_mean, f'Public Score Mean: {public_score_mean:.3f}', va='center', ha='right', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
plt.text(len(df), private_score_mean, f'Private Score Mean: {private_score_mean:.3f}', va='center', ha='right', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

plt.title('Public and Private Scores with Mean')
plt.xlabel('Iteration')
plt.ylabel('Score')
plt.xticks(np.arange(0, len(df), step=1))  # Ajusta los ticks del eje x para que vayan de 1 en 1
plt.legend()

# Muestra el gráfico
plt.show()

# %%
plt.figure(figsize=(10, 6))
index = df.index
plt.plot(index + 1, df['Public Score'], marker='o', label='Public Score')
plt.plot(index + 1, df['Private Score'], marker='o', label='Private Score')

# Añade las líneas de la media
public_score_mean = df['Public Score'].mean()
private_score_mean = df['Private Score'].mean()
plt.axhline(public_score_mean, color='blue', linestyle='dashed', linewidth=1)
plt.axhline(private_score_mean, color='orange', linestyle='dashed', linewidth=1)

# Añade las etiquetas de la media
plt.text(len(df) + 1, public_score_mean, f'Public Score Mean: {public_score_mean:.3f}', va='center', ha='right', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
plt.text(len(df) + 1, private_score_mean, f'Private Score Mean: {private_score_mean:.3f}', va='center', ha='right', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

plt.title('Public and Private Scores with Mean')
plt.xlabel('Iteration')
plt.ylabel('Score')
plt.xticks(index + 1)  # Ajusta los ticks del eje x para que coincidan con las posiciones de las barras
plt.legend()

# Muestra el gráfico
plt.show()

# %%
plt.figure(figsize=(10, 6))
index = df.index
plt.plot(index + 1, df['Public Score'], marker='o', label='Public Score')
plt.plot(index + 1, df['Private Score'], marker='o', label='Private Score')

# Añade las puntuaciones a cada punto
for i, score in enumerate(df['Public Score']):
    plt.text(i + 1, score, str(round(score, 3)), ha='center', va='bottom')
for i, score in enumerate(df['Private Score']):
    plt.text(i + 1, score, str(round(score, 3)), ha='center', va='top')

# Añade las líneas de la media
public_score_mean = df['Public Score'].mean()
private_score_mean = df['Private Score'].mean()
plt.axhline(public_score_mean, color='blue', linestyle='dashed', linewidth=1)
plt.axhline(private_score_mean, color='orange', linestyle='dashed', linewidth=1)

# Añade las etiquetas de la media
# plt.text(len(df) + 1, public_score_mean, f'Public Score Mean: {public_score_mean:.3f}', va='center', ha='right', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
# plt.text(len(df) + 1, private_score_mean, f'Private Score Mean: {private_score_mean:.3f}', va='center', ha='right', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

plt.title('Public and Private Scores with Mean')
plt.xlabel('Iteration')
plt.ylabel('Score')
plt.xticks(index + 1)  # Ajusta los ticks del eje x para que coincidan con las posiciones de las barras
plt.legend()

# Muestra el gráfico
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(index + 1, df['Public Score'], marker='o', label='Public Score')
plt.plot(index + 1, df['Private Score'], marker='o', label='Private Score')

# Añade las puntuaciones a cada punto
for i, score in enumerate(df['Public Score']):
    plt.text(i + 1, score, str(round(score, 3)), ha='center', va='bottom')
for i, score in enumerate(df['Private Score']):
    plt.text(i + 1, score, str(round(score, 3)), ha='center', va='top')

# Añade las líneas de la media
public_score_mean = df['Public Score'].mean()
private_score_mean = df['Private Score'].mean()
plt.axhline(public_score_mean, color='blue', linestyle='dashed', linewidth=1, label=f'Public Score Mean: {public_score_mean:.3f}')
plt.axhline(private_score_mean, color='orange', linestyle='dashed', linewidth=1, label=f'Private Score Mean: {private_score_mean:.3f}')

plt.title('Evolución de los resultados en Kaggle')
plt.xlabel('Submissions')
plt.ylabel('Accuracy')
plt.xticks(index + 1)  # Ajusta los ticks del eje x para que coincidan con las posiciones de las barras
plt.legend()

# Muestra el gráfico
plt.show()

# %%
index = df.index
fig, axs = plt.subplots(2, 1, figsize=(10, 12))

# Gráfico de líneas
axs[0].plot(index + 1, df['Public Score'], marker='o', label='Public Score')
axs[0].plot(index + 1, df['Private Score'], marker='o', label='Private Score')

# Añade las puntuaciones a cada punto
for i, score in enumerate(df['Public Score']):
    axs[0].text(i + 1, score, str(round(score, 3)), ha='center', va='bottom')
for i, score in enumerate(df['Private Score']):
    axs[0].text(i + 1, score, str(round(score, 3)), ha='center', va='top')

# Añade las líneas de la media
public_score_mean = df['Public Score'].mean()
private_score_mean = df['Private Score'].mean()
axs[0].axhline(public_score_mean, color='blue', linestyle='dashed', linewidth=1, label=f'Public Score Mean: {public_score_mean:.3f}')
axs[0].axhline(private_score_mean, color='orange', linestyle='dashed', linewidth=1, label=f'Private Score Mean: {private_score_mean:.3f}')

axs[0].set_title('Evolución de los resultados en Kaggle (Líneas)')
axs[0].set_xlabel('Submissions')
axs[0].set_ylabel('Accuracy')
axs[0].set_xticks(index + 1)  # Ajusta los ticks del eje x para que coincidan con las posiciones de las barras
axs[0].legend()

# Gráfico de barras
bar_width = 0.35
axs[1].bar(index + 1 - bar_width/2, df['Public Score'], bar_width, label='Public Score')
axs[1].bar(index + 1 + bar_width/2, df['Private Score'], bar_width, label='Private Score')

# Añade las líneas de la media
axs[1].axhline(public_score_mean, color='blue', linestyle='dashed', linewidth=1, label=f'Public Score Mean: {public_score_mean:.3f}')
axs[1].axhline(private_score_mean, color='orange', linestyle='dashed', linewidth=1, label=f'Private Score Mean: {private_score_mean:.3f}')

axs[1].set_title('Evolución de los resultados en Kaggle (Barras)')
axs[1].set_xlabel('Submissions')
axs[1].set_ylabel('Accuracy')
axs[1].set_xticks(index + 1)  # Ajusta los ticks del eje x para que coincidan con las posiciones de las barras
axs[1].legend()

# Muestra los gráficos
plt.tight_layout()
plt.show()

# %%
index = df.index
fig, axs = plt.subplots(1, 2, figsize=(20, 6))

# Gráfico de líneas
axs[0].plot(index + 1, df['Public Score'], marker='o', label='Public Score')
axs[0].plot(index + 1, df['Private Score'], marker='o', label='Private Score')

# Añade las puntuaciones a cada punto
for i, score in enumerate(df['Public Score']):
    axs[0].text(i + 1, score, str(round(score, 3)), ha='center', va='bottom')
for i, score in enumerate(df['Private Score']):
    axs[0].text(i + 1, score, str(round(score, 3)), ha='center', va='top')

# Añade las líneas de la media
axs[0].axhline(public_score_mean, color='blue', linestyle='dashed', linewidth=1, label=f'Public Score Mean: {public_score_mean:.3f}')
axs[0].axhline(private_score_mean, color='orange', linestyle='dashed', linewidth=1, label=f'Private Score Mean: {private_score_mean:.3f}')

axs[0].set_title('Evolución de los resultados en Kaggle (Líneas)')
axs[0].set_xlabel('Submissions')
axs[0].set_ylabel('Accuracy')
axs[0].set_xticks(index + 1)  # Ajusta los ticks del eje x para que coincidan con las posiciones de las barras
axs[0].legend()

# Gráfico de barras
bar_width = 0.35
axs[1].bar(index + 1 - bar_width/2, df['Public Score'], bar_width, label='Public Score')
axs[1].bar(index + 1 + bar_width/2, df['Private Score'], bar_width, label='Private Score')

# Añade las líneas de la media
public_score_mean = df['Public Score'].mean()
private_score_mean = df['Private Score'].mean()
axs[1].axhline(public_score_mean, color='blue', linestyle='dashed', linewidth=1, label=f'Public Score Mean: {public_score_mean:.3f}')
axs[1].axhline(private_score_mean, color='orange', linestyle='dashed', linewidth=1, label=f'Private Score Mean: {private_score_mean:.3f}')

axs[1].set_title('Evolución de los resultados en Kaggle (Barras)')
axs[1].set_xlabel('Submissions')
axs[1].set_ylabel('Accuracy')
axs[1].set_xticks(index + 1)  # Ajusta los ticks del eje x para que coincidan con las posiciones de las barras
axs[1].legend()

# Muestra los gráficos
plt.tight_layout()
plt.show()

# %%
# Gráfico de líneas
fig, ax = plt.subplots(figsize=(10, 6))
index = df.index
colores = ['dodgerblue', 'limegreen', 'black','blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'skyblue', 'limegreen', 'darkviolet']

sns.lineplot(x=index + 1, y=df['Public Score'], marker='o', ax=ax, color= colores[0], label='Public Score')
sns.lineplot(x=index + 1, y=df['Private Score'], marker='o', ax=ax, color= colores[1], label='Private Score')

# Añade las puntuaciones a cada punto
for i, score in enumerate(df['Public Score']):
    ax.text(i + 1, score + 0.001, str(round(score, 3)), ha='center', va='bottom', fontsize=12, color= color_line[0])
for i, score in enumerate(df['Private Score']):
    ax.text(i + 1, score - 0.001, str(round(score, 3)), ha='center', va='top', fontsize=12, color= color_line[0])

# Añade las líneas de la media
public_score_mean = df['Public Score'].mean()
private_score_mean = df['Private Score'].mean()
ax.axhline(public_score_mean, color= colores[0], linestyle='dashed', linewidth=1, label=f'Public Score Mean: {public_score_mean:.3f}')
ax.axhline(private_score_mean, color= colores[1], linestyle='dashed', linewidth=1, label=f'Private Score Mean: {private_score_mean:.3f}')

# Título del gráfico
plt.title('Evolución de los resultados en Kaggle', fontsize=16)
plt.xlabel('Submissions')
plt.ylabel('Accuracy')
plt.xticks(index + 1)  # Ajusta los ticks del eje x para que coincidan con las posiciones de las barras
plt.legend(title='', title_fontsize='13', loc='upper left')

# Muestra los gráficos
plt.show()

# %%
# Gráfico de líneas
fig, ax = plt.subplots(figsize=(10, 6))
colores = ['dodgerblue', 'limegreen', 'black','blue', 'orange', 'green', 'red', 'purple', 'skyblue','darkviolet', 'gold'] #'limegreen', 'gold', 'darkviolet', 'saddlebrown', 'hotpink', 'gray', 'olive', 'cyan']


f_melted = df.melt(value_vars=['Public Score', 'Private Score'], 
                    var_name='Score Type', 
                    value_name='Score')
df_melted['Index'] = list(range(1, len(df) + 1)) * 2
sns.barplot(x='Index', y='Score', hue='Score Type', data=df_melted, ax=ax, palette=colores[:2])

# Añade los valores a las barras
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.3f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height() / 2.), 
                   ha = 'center', va = 'center', 
                   color = 'white', rotation=90, fontsize=12)

# Añade las líneas de la media
public_score_mean = df['Public Score'].mean()
private_score_mean = df['Private Score'].mean()
ax.axhline(public_score_mean, color=colores[0], linestyle='dashed', linewidth=1, label=f'Public Score Mean: {public_score_mean:.3f}')
ax.axhline(private_score_mean, color=colores[1], linestyle='dashed', linewidth=1, label=f'Private Score Mean: {private_score_mean:.3f}')

# Añade el mayor valor
# max_value = df[['Public Score', 'Private Score']].max(axis=1).max()
# ax.axhline(max_value, color=colores[6], linestyle='dotted', linewidth=1, label=f'Max Score: {max_value:.3f}')

# Encuentra el valor más alto para cada variable y su índice
public_score_max = df['Public Score'].max()
private_score_max = df['Private Score'].max()
public_score_max_index = df['Public Score'].idxmax()
private_score_max_index = df['Private Score'].idxmax()

# Encuentra el valor más alto para cada variable
public_score_max = df['Public Score'].max()
private_score_max = df['Private Score'].max()

# Obtiene las barras correspondientes a los valores más altos
public_score_max_bars = [p for p in ax.patches if p.get_height() == public_score_max]
private_score_max_bars = [p for p in ax.patches if p.get_height() == private_score_max]

# Añade una flecha en la posición del valor más alto para cada variable
for bar in public_score_max_bars:
    ax.annotate('', xy=(bar.get_x() + bar.get_width() / 2, public_score_max), 
                xytext=(bar.get_x() + bar.get_width() / 2, public_score_max + 0.03),
                arrowprops=dict(facecolor = colores[3], edgecolor = colores[3], arrowstyle='->', lw=1.5))

for bar in private_score_max_bars:
    ax.annotate('', xy=(bar.get_x() + bar.get_width() / 2, private_score_max), 
                xytext=(bar.get_x() + bar.get_width() / 2, private_score_max + 0.035),
                arrowprops=dict(facecolor = colores[6], edgecolor = colores[6], arrowstyle='->', lw=1.5))

# Título del gráfico
plt.title('Gráfico de los resultados de Kaggle', fontsize=16)
plt.xlabel('Submissions')
plt.ylabel('Accuracy')
plt.legend(title='', title_fontsize='13', loc='lower right')

# Muestra los gráficos
plt.show()
